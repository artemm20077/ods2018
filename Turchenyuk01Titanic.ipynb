# %%
import numpy as np
import pandas as pd
# %matplotlib inline
# %precision 2
# Out:
# '%.2f'

# %%
data = pd.read_csv('D:/titanic_train.csv')

# %%
data.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data[(data['Embarked'] == 'C') & (data.Fare > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.5208          B58 B60        C
# 259              0      0  PC 17755  512.3292              NaN        C
# ...

# %%
data[(data['Embarked'] == 'C') & 
     (data['Fare'] > 200)].sort_values(by='Fare',
                               ascending=False).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292              NaN        C
# 680          36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292             B101        C
# 312          18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data[(data['Sex'] ==1 ) & (data['Pclass'] == 2)].describe()
# Out:
#          Survived  Pclass    Sex        Age       SibSp       Parch  \
# count  108.000000   108.0  108.0  99.000000  108.000000  108.000000
# mean     0.157407     2.0    1.0  30.740707    0.342593    0.222222
# std      0.365882     0.0    0.0  14.793894    0.566380    0.517603
# min      0.000000     2.0    1.0   0.670000    0.000000    0.000000
# 25%      0.000000     2.0    1.0  23.000000    0.000000    0.000000
# 50%      0.000000     2.0    1.0  30.000000    0.000000    0.000000
# 75%      0.000000     2.0    1.0  36.750000    1.000000    0.000000
# max      1.000000     2.0    1.0  70.000000    2.000000    2.000000
#
#              Fare
# count  108.000000
# mean    19.741782
# std     14.922235
# min      0.000000
# 25%     12.331250
# 50%     13.000000
# 75%     26.000000
# max     73.500000

# %%
data[(data['Sex'] ==0 ) & (data['Pclass'] == 2)].describe()
# Out:
#         Survived  Pclass   Sex        Age      SibSp      Parch       Fare
# count  76.000000    76.0  76.0  74.000000  76.000000  76.000000  76.000000
# mean    0.921053     2.0   0.0  28.722973   0.486842   0.605263  21.970121
# std     0.271448     0.0   0.0  12.872702   0.642774   0.833930  10.891796
# min     0.000000     2.0   0.0   2.000000   0.000000   0.000000  10.500000
# 25%     1.000000     2.0   0.0  22.250000   0.000000   0.000000  13.000000
# 50%     1.000000     2.0   0.0  28.000000   0.000000   0.000000  22.000000
# 75%     1.000000     2.0   0.0  36.000000   1.000000   1.000000  26.062500
# max     1.000000     2.0   0.0  57.000000   3.000000   3.000000  65.000000

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# %precision 2
# Out:
# '%.2f'

# %%
data['Fare'].median()
# Out:
# 14.45

# %%
# %precision 2
# Out:
# '%.2f'

# %%
def age_category(age):
    '''
    <= 30 -> 1
    > 30, <60 -> 2
    >= 60 -> 3
    '''
    if age <= 30:
        return 1
    elif age < 60:
        return 2
    else:
        return 3

# %%
age_categories = [age_category(age) for age in data.Age]

# %%
data['Age_category'] = age_categories

# %%
data['Pclass'].value_counts()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
data['Age_category'].value_counts()
# Out:
# 3    456
# 1    409
# 2     26
# Name: Age_category, dtype: int64

# %%
data[(data['Age_category'] ==1 ) & (data['Survived'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166 entries, 2 to 889
# Data columns (total 13 columns):
# PassengerId     166 non-null int64
# Survived        166 non-null int64
# Pclass          166 non-null int64
# Name            166 non-null object
# Sex             166 non-null object
# Age             166 non-null float64
# SibSp           166 non-null int64
# Parch           166 non-null int64
# Ticket          166 non-null object
# Fare            166 non-null float64
# Cabin           53 non-null object
# Embarked        166 non-null object
# Age_category    166 non-null int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 14.9+ KB

# %%
for look, sub_df in data.groupby(['Survived', 'Age_category']):
    print(look)
    print(sub_df['Age_category'].value_counts())
# Out:
# (0, 1)
# 1    243
# Name: Age_category, dtype: int64
# (0, 2)
# 2    19
# Name: Age_category, dtype: int64
# (0, 3)
# 3    287
# Name: Age_category, dtype: int64
# (1, 1)
# 1    166
# Name: Age_category, dtype: int64
# (1, 2)
# 2    7
# Name: Age_category, dtype: int64
# (1, 3)
# 3    169
# Name: Age_category, dtype: int64

# %%
for look, sub_df in data.groupby(['Sex', 'Age_category']):
    print(look)
    print(sub_df['Age_category'].value_counts())
# Out:
# ('female', 1)
# 1    158
# Name: Age_category, dtype: int64
# ('female', 2)
# 2    4
# Name: Age_category, dtype: int64
# ('female', 3)
# 3    152
# Name: Age_category, dtype: int64
# ('male', 1)
# 1    251
# Name: Age_category, dtype: int64
# ('male', 2)
# 2    22
# Name: Age_category, dtype: int64
# ('male', 3)
# 3    304
# Name: Age_category, dtype: int64

# %%
pd.crosstab(data['Survived'], data['Age_category'])
# Out:
# Age_category    1   2    3
# Survived
# 0             243  19  287
# 1             166   7  169

# %%
def get_title(name):
    if pd.isnull(name):
        return "Null"

    title_search = re.search(' ([A-Za-z]+)\.', name)
    if title_search:
        return title_search.group(1).lower()
    else:
        return "None"

# %%
pd.crosstab(data['Name'], data['Sex'])
# Out:
# Sex                                              female  male
# Name
# Abbing, Mr. Anthony                                   0     1
# Abbott, Mr. Rossmore Edward                           0     1
# Abbott, Mrs. Stanton (Rosa Hunt)                      1     0
# Abelson, Mr. Samuel                                   0     1
# Abelson, Mrs. Samuel (Hannah Wizosky)                 1     0
# Adahl, Mr. Mauritz Nils Martin                        0     1
# Adams, Mr. John                                       0     1
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)        1     0
# Aks, Mrs. Sam (Leah Rosen)                            1     0
# Albimona, Mr. Nassef Cassem                           0     1
# Alexander, Mr. William                                0     1
# Alhomaki, Mr. Ilmari Rudolf                           0     1
# Ali, Mr. Ahmed                                        0     1
# Ali, Mr. William                                      0     1
# ...

# %%
d= {1: 'Alfons', 0: 'Hileni'}

# %%
data['Name'].map(d).head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Name, dtype: object
